# %% [markdown]
# # Descriptive statistics problems

# %%
# imports
import numpy as np
import pandas as pd
import seaborn as sns
import statistics as stats
from scipy.stats import skew, kurtosis

# data types
from numpy import float64
from numpy._typing._array_like import NDArray

# %% [markdown]
# ### Exercise 1
#
# We will use NumPy to obtain information to describe statistically.
#
# - Generate an array of 100 elements following a normal distribution.
# - Generate an array of 100 elements following a chi-square distribution with 3 degrees of freedom.
# - Calculate the main metrics and statistical measures that best describe the two vectors.

# %%
# normal distribution
normal_dist: NDArray[float64] = np.random.normal(loc=0, scale=0.1, size=100)
# calculating the values
print('Normal distribution:')
print(f'    Mean: {normal_dist.mean()}')
print(f'    Variance: {stats.variance(normal_dist)}')
print(f'    Standard deviation: {np.std(normal_dist, ddof=1)}')
print(f'    Median: {np.median(normal_dist)}')
print(f'    Mode: {stats.mode(normal_dist)}')
print(f'    Skewness: {skew(normal_dist)}')
print(f'    Skew: {kurtosis(normal_dist)}')

# chi distribution
chi_dist: NDArray[float64] = np.random.chisquare(df=3, size=100)
print('\nChisquare distribution:')
print(f'    Mean: {chi_dist.mean()}')
print(f'    Variance: {stats.variance(chi_dist)}')
print(f'    Standard deviation: {np.std(chi_dist, ddof=1)}')
print(f'    Median: {np.median(chi_dist)}')
print(f'    Mode: {stats.mode(chi_dist)}')
print(f'    Skewness: {skew(chi_dist)}')
print(f'    Skew: {kurtosis(chi_dist)}')
# Out:
# Normal distribution:
#     Mean: 0.0037423068750892952
#     Variance: 0.009104239659508054
#     Standard deviation: 0.0954161394079013
#     Median: 0.00294510865317255
#     Mode: 0.03944380256439703
#     Skewness: -0.1655131255841742
#     Skew: -0.4364329480642457
#
# Chisquare distribution:
#     Mean: 3.0043585089440024
#     Variance: 4.451057431476181
#     Standard deviation: 2.1097529313822934
#     Median: 2.541160026756364
#     Mode: 2.2698917612113125
#     Skewness: 1.4733530165774782
#     Skew: 2.8711282873388777

# %% [markdown]
# ### Graph the distributions

# %%
def graph(x:pd.DataFrame, column_name: str, kde: bool = False) -> None:
  '''Graph the function using seaborn'''
  sns.displot(data=x, x=column_name, kde=kde)

# %%
# transform the dist to a dataframe
column_name = 'x'
x_as_df: pd.DataFrame = pd.DataFrame(data=normal_dist, columns=[column_name])
# graph them using seaborn
graph(x=x_as_df, column_name=column_name, kde=True)

# %%
# transform the dist to a dataframe
column_name = 'x'
x_as_df: pd.DataFrame = pd.DataFrame(data=chi_dist, columns=[column_name])
# graph them using seaborn
graph(x=x_as_df, column_name=column_name, kde=True)

# %% [markdown]
# ### Exercise 2
#
# Write a Python program to calculate the standard deviation of the following data:
#
# ```py
# data = [4, 2, 5, 8, 6]
# ```

# %%
# set the data
data = pd.Series([4, 2, 5, 8, 6])

# %%
def calculate_standard_deviation(data_series: 'pd.Series[int]') -> float:
    '''Calculate the standard deviation of an array'''
    # calculate the mean 
    u: float = data_series.sum()/len(data_series)
    # calculate the square difference from the value to the mean
    diff: pd.Series[float] = (data_series - u) ** 2
    # calculate the variance
    o2: float = diff.sum()/len(data_series)
    # calculate the square root
    o: float = o2 ** 0.5

    return o

# %%
# call t function
result = calculate_standard_deviation(data_series=data)
print(f'Standard deviation is: {result}')
# Out:
# Standard deviation is: 2.0
